# %% [markdown]
# <a href="https://colab.research.google.com/github/drshaheed/ICC-Batters/blob/main/ICC_TOP_100_Batters.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Top 100 Batsman | Data analysis and Visualizations**

# %%
# Importing Dependencies
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import os

# %%
#Loading the Data
df = pd.read_csv('/content/drive/MyDrive/Data Colab/top100batsman.csv')

# %%
#Getting Overview of Data Structure
df.head()
# Out:
#    test_ranking   player_id             batsman  rating         team  matches  \
# 0              1      10182  Marnus Labuschagne     925    AUSTRALIA       33
# 1              2       2250        Steven Smith     883    AUSTRALIA       92
# 2              3       8359          Babar Azam     882     PAKISTAN       47
# 3              4       8497         Travis Head     833    AUSTRALIA       33
# 4              5       6326     Kane Williamson     828  NEW ZEALAND       90
#
#    innings  runs  high_score  average  strike_rate  century  double_century  \
# 0       56  3150         215    59.43        55.73       10               2
# 1      162  8647         239    60.89        54.38       30               4
# 2       85  3696         196    48.63        55.03        9               0
# 3       51  2126         175    45.23        61.14        5               0
# 4      157  7645         251    53.84        51.07       25               5
#
#    half_century  fours  sixes
# 0            14    344     10
# 1            37    942     49
# 2            26    430     22
# 3            12    247     11
# 4            33    850     18

# %%
#Checking for Null Values
df.isnull().sum()
# Out:
# test_ranking      0
# player_id         0
# batsman           0
# rating            0
# team              0
# matches           0
# innings           0
# runs              0
# high_score        0
# average           0
# strike_rate       0
# century           0
# double_century    0
# half_century      0
# fours             0
# sixes             0
# dtype: int64

# %% [markdown]
# # **Exploratory Data Analysis**

# %%
df.shape
# Out:
# (100, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   test_ranking    100 non-null    int64
#  1   player_id       100 non-null    int64
#  2   batsman         100 non-null    object
#  3   rating          100 non-null    int64
#  4   team            100 non-null    object
#  5   matches         100 non-null    int64
#  6   innings         100 non-null    int64
#  7   runs            100 non-null    int64
#  8   high_score      100 non-null    int64
#  9   average         100 non-null    float64
#  10  strike_rate     100 non-null    float64
#  11  century         100 non-null    int64
#  12  double_century  100 non-null    int64
#  13  half_century    100 non-null    int64
#  14  fours           100 non-null    int64
#  15  sixes           100 non-null    int64
# dtypes: float64(2), int64(12), object(2)
# memory usage: 12.6+ KB

# %%
df.describe()
# Out:
#        test_ranking      player_id      rating     matches     innings  \
# count     100.000000    100.000000  100.000000  100.000000  100.000000
# mean       50.500000   7440.520000  562.210000   38.830000   68.630000
# std        29.011492   3770.870747  134.491733   29.415537   52.729854
# min         1.000000    394.000000  382.000000    1.000000    1.000000
# 25%        25.750000   6305.750000  447.250000   16.000000   26.000000
# 50%        50.500000   8359.000000  542.500000   31.500000   54.500000
# 75%        75.250000   9646.000000  637.500000   54.250000   95.000000
# max       100.000000  16414.000000  925.000000  127.000000  233.000000
#
#                runs  high_score     average  strike_rate    century  \
# count    100.000000  100.000000  100.000000   100.000000  100.00000
# mean    2452.750000  157.270000   38.870600    52.630200    5.48000
# std     2225.511143   57.129811   11.766165     9.901994    6.64311
# min       61.000000   61.000000   23.840000    34.220000    0.00000
# 25%      875.750000  110.750000   30.507500    46.362500    1.00000
# 50%     1552.500000  152.500000   36.770000    52.120000    3.00000
# 75%     3140.250000  199.250000   43.392500    56.447500    8.00000
# max    10629.000000  335.000000   97.000000    92.130000   30.00000
#
#        double_century  half_century        fours       sixes
# count      100.000000     100.00000   100.000000  100.000000
# mean         0.530000      12.46000   279.330000   16.290000
# std          1.226434      10.91049   249.139532   18.381092
# min          0.000000       1.00000     7.000000    0.000000
# 25%          0.000000       4.00000   101.000000    4.000000
# 50%          0.000000       8.50000   180.500000   11.000000
# 75%          0.250000      18.25000   344.750000   22.000000
# max          7.000000      55.00000  1179.000000  107.000000

# %% [markdown]
# **Getting rid of unneccesary columns**

# %%
del df['rating']
del df['player_id']

# %% [markdown]
# ## **Top 10 Batsman who has scored most runs in test**

# %%
df.sort_values(by = 'runs',ascending=False).head(10)
# Out:
#     test_ranking              batsman         team  matches  innings   runs  \
# 5               6            Joe Root      ENGLAND      127      233  10629
# 1               2        Steven Smith    AUSTRALIA       92      162   8647
# 13             14        David Warner    AUSTRALIA      101      184   8132
# 14             15         Virat Kohli        INDIA      104      177   8119
# 4               5     Kane Williamson  NEW ZEALAND       90      157   7645
# 34             35           Azhar Ali     PAKISTAN       97      180   7142
# 20             21   Cheteshwar Pujara        INDIA       98      168   7014
# 17             18      Angelo Mathews    SRI LANKA      100      178   6953
# 7               8  Dimuth Karunaratne    SRI LANKA       82      158   6023
# 25             26          Ben Stokes      ENGLAND       89      162   5602
#
#     high_score  average  strike_rate  century  double_century  half_century  \
# 5          254    49.44        55.70       28               5            55
# 1          239    60.89        54.38       30               4            37
# 13         335    46.20        71.38       25               3            34
# 14         254    48.91        55.50       27               7            28
# 4          251    53.84        51.07       25               5            33
# 34         302    42.26        41.93       19               3            35
# 20         206    44.39        44.44       19               3            34
# 17         200    45.15        48.23       13               1            38
# 7          244    39.62        50.06       14               1            31
# 25         258    36.14        58.94       12               1            28
#
#     fours  sixes
# 5    1179     28
# 1     942     49
# 13    957     64
# 14    913     24
# 4     850     18
# 34    695     22
# 20    843     15
# 17    716     75
# 7     628      9
# 25    669    107

# %% [markdown]
# **Top 10 Batsman with Highest runs in test**

# %%
df.sort_values(by = 'high_score',ascending = False).head(10)
# Out:
#     test_ranking              batsman         team  matches  innings   runs  \
# 13             14        David Warner    AUSTRALIA      101      184   8132
# 34             35           Azhar Ali     PAKISTAN       97      180   7142
# 51             52         Zak Crawley      ENGLAND       31       57   1598
# 19             20          Tom Latham  NEW ZEALAND       70      123   4904
# 25             26          Ben Stokes      ENGLAND       89      162   5602
# 5               6            Joe Root      ENGLAND      127      233  10629
# 14             15         Virat Kohli        INDIA      104      177   8119
# 4               5     Kane Williamson  NEW ZEALAND       90      157   7645
# 7               8  Dimuth Karunaratne    SRI LANKA       82      158   6023
# 26             27      Mayank Agarwal        INDIA       21       36   1488
#
#     high_score  average  strike_rate  century  double_century  half_century  \
# 13         335    46.20        71.38       25               3            34
# 34         302    42.26        41.93       19               3            35
# 51         267    28.54        57.94        3               1             7
# 19         264    41.91        47.45       13               2            25
# 25         258    36.14        58.94       12               1            28
# 5          254    49.44        55.70       28               5            55
# 14         254    48.91        55.50       27               7            28
# 4          251    53.84        51.07       25               5            33
# 7          244    39.62        50.06       14               1            31
# 26         243    41.33        53.49        4               2             6
#
#     fours  sixes
# 13    957     64
# 34    695     22
# 51    230      1
# 19    559     17
# 25    669    107
# 5    1179     28
# 14    913     24
# 4     850     18
# 7     628      9
# 26    189     28

# %% [markdown]
# **Player who played most number of matches**

# %%
df.sort_values(by = 'matches',ascending = False).head()
# Out:
#     test_ranking             batsman       team  matches  innings   runs  \
# 5               6           Joe Root    ENGLAND      127      233  10629
# 14             15        Virat Kohli      INDIA      104      177   8119
# 13             14       David Warner  AUSTRALIA      101      184   8132
# 17             18     Angelo Mathews  SRI LANKA      100      178   6953
# 20             21  Cheteshwar Pujara      INDIA       98      168   7014
#
#     high_score  average  strike_rate  century  double_century  half_century  \
# 5          254    49.44        55.70       28               5            55
# 14         254    48.91        55.50       27               7            28
# 13         335    46.20        71.38       25               3            34
# 17         200    45.15        48.23       13               1            38
# 20         206    44.39        44.44       19               3            34
#
#     fours  sixes
# 5    1179     28
# 14    913     24
# 13    957     64
# 17    716     75
# 20    843     15

# %% [markdown]
# ### Number of the player who have scored runs more than average

# %%
print(len(df[df['runs'] >= df['runs'].mean()]['batsman']))
# Out:
# 38

# %% [markdown]
# **Names of the player who have scored runs more than average**

# %%
df[df['runs'] >= df['runs'].mean()]['batsman'].head()
# Out:
# 0    Marnus Labuschagne
# 1          Steven Smith
# 2            Babar Azam
# 4       Kane Williamson
# 5              Joe Root
# Name: batsman, dtype: object

# %% [markdown]
# **Names of the player who has player more than average number of matches and has strike rate more than average**

# %%
df.head(2)
# Out:
#    test_ranking              batsman       team  matches  innings  runs  \
# 0              1  Marnus Labuschagne  AUSTRALIA       33       56  3150
# 1              2        Steven Smith  AUSTRALIA       92      162  8647
#
#    high_score  average  strike_rate  century  double_century  half_century  \
# 0         215    59.43        55.73       10               2            14
# 1         239    60.89        54.38       30               4            37
#
#    fours  sixes
# 0    344     10
# 1    942     49

# %%
avg_matches      = sum(df.values[:,3])//len(df.values[:,3])
avg_strike_rate  = sum(df.values[:,8])//len(df.values[:,8])

player_ = []
for i in df.values:
    if (i[3] >= avg_matches) and i[8] >= avg_strike_rate:
        player_.append([i[1],i[2],i[3],i[8]])
        
top_players = pd.DataFrame(player_,columns = ['name','team','matches','strike_rate'])
top_players
# Out:
#                    name         team  matches  strike_rate
# 0          Steven Smith    AUSTRALIA       92        54.38
# 1            Babar Azam     PAKISTAN       47        55.03
# 2              Joe Root      ENGLAND      127        55.70
# 3          Rohit Sharma        INDIA       45        55.77
# 4        Jonny Bairstow      ENGLAND       89        57.58
# 5          David Warner    AUSTRALIA      101        71.38
# 6           Virat Kohli        INDIA      104        55.50
# 7            Ben Stokes      ENGLAND       89        58.94
# 8       Ravindra Jadeja        INDIA       60        59.50
# 9   Dhananjaya de Silva    SRI LANKA       45        56.62
# 10      Shakib Al Hasan   BANGLADESH       65        61.55
# 11          Tamim Iqbal   BANGLADESH       69        58.07
# 12   Jermaine Blackwood  WEST INDIES       50        53.66
# 13   Niroshan Dickwella    SRI LANKA       53        66.57
# 14             KL Rahul        INDIA       45        52.07
# 15         Kusal Mendis    SRI LANKA       54        55.21
# 16          Mahmudullah   BANGLADESH       50        53.41
# 17        Mominul Haque   BANGLADESH       55        53.29
# 18       Sarfaraz Ahmed     PAKISTAN       51        70.28
# 19          Jos Buttler      ENGLAND       57        54.18
# 20         Jason Holder  WEST INDIES       58        55.57
# 21  Ravichandran Ashwin        INDIA       88        54.64
# 22         Chris Woakes      ENGLAND       45        52.23
# 23           Babar Azam     PAKISTAN       47        55.03

# %% [markdown]
# **Sixes per innings**

# %%
six_per_inning = np.array(round(df['sixes']/df['innings'],3))
df['six_per_inning'] = six_per_inning
df.head()
# Out:
#    test_ranking              batsman         team  matches  innings  runs  \
# 0              1  Marnus Labuschagne    AUSTRALIA       33       56  3150
# 1              2        Steven Smith    AUSTRALIA       92      162  8647
# 2              3          Babar Azam     PAKISTAN       47       85  3696
# 3              4         Travis Head    AUSTRALIA       33       51  2126
# 4              5     Kane Williamson  NEW ZEALAND       90      157  7645
#
#    high_score  average  strike_rate  century  double_century  half_century  \
# 0         215    59.43        55.73       10               2            14
# 1         239    60.89        54.38       30               4            37
# 2         196    48.63        55.03        9               0            26
# 3         175    45.23        61.14        5               0            12
# 4         251    53.84        51.07       25               5            33
#
#    fours  sixes  six_per_inning
# 0    344     10           0.179
# 1    942     49           0.302
# 2    430     22           0.259
# 3    247     11           0.216
# 4    850     18           0.115

# %% [markdown]
# **Fours per innings**

# %%
fours_per_inning = np.array(round(df['fours']/df['innings'],3))
df['fours_per_inning'] = fours_per_inning
df.head()
# Out:
#    test_ranking              batsman         team  matches  innings  runs  \
# 0              1  Marnus Labuschagne    AUSTRALIA       33       56  3150
# 1              2        Steven Smith    AUSTRALIA       92      162  8647
# 2              3          Babar Azam     PAKISTAN       47       85  3696
# 3              4         Travis Head    AUSTRALIA       33       51  2126
# 4              5     Kane Williamson  NEW ZEALAND       90      157  7645
#
#    high_score  average  strike_rate  century  double_century  half_century  \
# 0         215    59.43        55.73       10               2            14
# 1         239    60.89        54.38       30               4            37
# 2         196    48.63        55.03        9               0            26
# 3         175    45.23        61.14        5               0            12
# 4         251    53.84        51.07       25               5            33
#
#    fours  sixes  six_per_inning  fours_per_inning
# 0    344     10           0.179             6.143
# 1    942     49           0.302             5.815
# 2    430     22           0.259             5.059
# 3    247     11           0.216             4.843
# 4    850     18           0.115             5.414

# %% [markdown]
# **Top 5 player with most number of fours per innings**

# %%
df.sort_values(by='fours_per_inning',ascending = False).head(5)
# Out:
#     test_ranking          batsman         team  matches  innings  runs  \
# 90             91   Jamie Overton      ENGLAND        1        1    97
# 45             46     Harry Brook      ENGLAND        4        6   480
# 88             89  Kamindu Mendis    SRI LANKA        1        1    61
# 23             24    Devon Conway  NEW ZEALAND       12       22  1150
# 16             17    Shreyas Iyer        INDIA        7       12   624
#
#     high_score  average  strike_rate  century  double_century  half_century  \
# 90          97    97.00        71.32        0               0             1
# 45         153    80.00        92.13        3               0             1
# 88          61    61.00        44.53        0               0             1
# 23         200    54.76        52.56        4               1             5
# 16         105    56.73        65.14        1               0             5
#
#     fours  sixes  six_per_inning  fours_per_inning
# 90     13      2           2.000            13.000
# 45     55     12           2.000             9.167
# 88      7      0           0.000             7.000
# 23    149      4           0.182             6.773
# 16     76     11           0.917             6.333

# %% [markdown]
# Top 5 player with most number of sixes per innings

# %%
df.sort_values(by='six_per_inning',ascending = False).head(5)
# Out:
#     test_ranking               batsman         team  matches  innings  runs  \
# 90             91        Jamie Overton      ENGLAND        1        1    97
# 45             46          Harry Brook      ENGLAND        4        6   480
# 6               7         Rishabh Pant        INDIA       33       56  2271
# 35             36  Colin de Grandhomme  NEW ZEALAND       29       44  1432
# 16             17         Shreyas Iyer        INDIA        7       12   624
#
#     high_score  average  strike_rate  century  double_century  half_century  \
# 90          97    97.00        71.32        0               0             1
# 45         153    80.00        92.13        3               0             1
# 6          159    43.67        73.61        5               0            11
# 35         120    38.70        80.45        2               0             8
# 16         105    56.73        65.14        1               0             5
#
#     fours  sixes  six_per_inning  fours_per_inning
# 90     13      2           2.000            13.000
# 45     55     12           2.000             9.167
# 6     247     55           0.982             4.411
# 35    141     41           0.932             3.205
# 16     76     11           0.917             6.333

# %% [markdown]
# **Group by Country**

# %%
teams = []
for i in df['team']:
    teams.append(i)
    
teams = list(set(teams))
print(teams)
# Out:
# ['BANGLADESH', 'NEW ZEALAND', 'WEST INDIES', 'ZIMBABWE', 'ENGLAND', 'SRI LANKA', 'AFGHANISTAN', 'INDIA', 'PAKISTAN', 'AUSTRALIA', 'SOUTH AFRICA']

# %%
data = []
for team in teams:
    c = 0
    match = 0
    for i in df.values:
        if team in (i[2]):
            c += 1
            match += i[3]
            
    data.append([team,c,match,match//c])
df_ = pd.DataFrame(data,columns =['team','number_of_player','total_matches','avg_match_per_player'])
df_.sort_values(by ='number_of_player',ascending= False)
# Out:
#             team  number_of_player  total_matches  avg_match_per_player
# 4        ENGLAND                15            586                    39
# 7          INDIA                13            616                    47
# 8       PAKISTAN                12            400                    33
# 5      SRI LANKA                11            499                    45
# 9      AUSTRALIA                11            456                    41
# 2    WEST INDIES                 9            336                    37
# 0     BANGLADESH                 8            390                    48
# 1    NEW ZEALAND                 8            299                    37
# 10  SOUTH AFRICA                 8            239                    29
# 3       ZIMBABWE                 3             53                    17
# 6    AFGHANISTAN                 2              9                     4

# %% [markdown]
# #** Data Visualisation**

# %% [markdown]
# **Players with most runs**

# %%
df_runs  = df.sort_values(by = 'runs',ascending=False).head(10)
runs     = np.array(df_runs['runs'])
player   = np.array(df_runs['batsman'])

plt.subplots(figsize = (16,4))
plt.bar(player,runs)
plt.xlabel('batsmen')
plt.ylabel('runs')
plt.show()

# %% [markdown]
# **Team distribution of player**

# %%
team       = df_['team'] 
tot_player = df_['number_of_player']

plt.pie(tot_player, labels=team,autopct='%1.2f')

plt.show()

# %% [markdown]
# **Most number of double century**

# %%
df_double_century  = df.sort_values(by = 'double_century',ascending=False).head()

d_c    = df_double_century.values[:,10]
player = df_double_century.values[:,1]

plt.plot(player,d_c)
plt.xlabel('player')
plt.ylabel('double century')
plt.show()
